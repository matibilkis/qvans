# %% [markdown]
# # Tutorial 1: VANs methods
#
# In this tutorial we will train VANs to find a quantum circuit that prepares the ground state of a TFIM, by departing from a separable circuit.

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow_quantum as tfq
import matplotlib.pyplot as plt
import cirq
import numpy as np

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
os.chdir("..")
print("USING TFQ {} VERSION ".format(tfq.__version__))
print("USING CIRQ {} VERSION ".format(cirq.__version__))
# Out:
# USING TFQ 0.4.0 VERSION
# USING CIRQ 0.9.1 VERSION

# %% [markdown]
# As in the previous tutorial, we will work with the TFIM
#
# $H=-J\sum_{j=1}^n \sigma_j^x\sigma_{j+1}^x-g\sum_{j=1}^n \sigma_j^x\,,$

# %% [markdown]
# ### Introducing the Evaluator
#
# Evaluator is a method that allows VANs to keep track of quantum circuit evolution, and eventually load results for future analysis. Moreover, it literally evaluates to whether or not accept a new quantum circuit according to some criteria. In this case, the criteria we have implemented is a very simple one: we accept modifications whose energy is $\epsilon$-close to the best energy found so far. The reason we do this is to favour exploration, and $\epsilon$ is decreased as VANs iterations evolve.
#
# Evaluator keeps a record of training according with two dictionaries: $\texttt{raw_history}$ and $\texttt{evolution}$. In $\texttt{raw_history}$ we keep everything, whereas in $\texttt{evolution}$ we keep only changes that are approved by the Evaluator. Either adding information to both dictionaries or not is controlled by the argument $relevant$ of the <i>add_step</i> function.
#
# Now let us go through the algorithm; this is explained in the paper but for the record we will put the pseudo-code

# %% [markdown]
# <img src="images/vans_algo.png" alt="Italian Trulli">

# %%
from utilities.circuit_basics import Basic, overlap
from utilities.variational import VQE 
from utilities.evaluator import Evaluator
from utilities.idinserter import IdInserter
from utilities.simplifier import Simplifier
from utilities.unitary_killer import UnitaryMurder
from utilities.evaluator import Evaluator

# %%
problem_config={"problem":"TFIM", "J":1.0, "g":1.0}

vqe_handler = VQE(n_qubits=4, epochs=2000, 
                  verbose=1,problem_config=problem_config,
                  optimizer="adam", lr=0.01)


dict_evaluator={"n_qubits":4,"problem_config":problem_config, "specific_name":"TFIM/{}Q - J {} g {}".format(vqe_handler.n_qubits, problem_config["J"], problem_config["g"])}

evaluator = Evaluator(dict_evaluator, path="examples_repository/", acceptance_percentage=1e-3, 
                      reduce_acceptance_percentage=True)

iid = IdInserter(n_qubits=len(vqe_handler.qubits),
                 selector_temperature = 10.0)

Simp = Simplifier(n_qubits=len(vqe_handler.qubits))

vqe_handler = VQE(n_qubits=4, epochs=5000, 
                  verbose=0,problem_config=problem_config,
                  optimizer="adam", lr=1e-2, patience=100)

unitary_killer = UnitaryMurder(vqe_handler, accept_wall=100)

# %% [markdown]
# We begin with a separable circuit

# %%
indexed_circuit = [vqe_handler.number_of_cnots+vqe_handler.n_qubits+k for k in range(vqe_handler.n_qubits)]
display(vqe_handler.give_circuit(indexed_circuit)[0])
# Out:
# (0, 0): ───Rx(th_0)───
#
# (0, 1): ───Rx(th_1)───
#
# (0, 2): ───Rx(th_2)───
#
# (0, 3): ───Rx(th_3)───

# %%
energy, symbol_to_value, training_history = vqe_handler.vqe(indexed_circuit)

## add step to evaluator ##
evaluator.add_step(indexed_circuit, symbol_to_value, energy, relevant=True)
evaluator.lowest_energy = energy

# %% [markdown]
# Now let us go on with the algorithm.

# %%
for iteration in range(5):
    M_indices, M_symbols_to_values, M_idx_to_symbols = iid.place_identities(indexed_circuit, symbol_to_value, rate_iids_per_step= 2.0)

    ### simplify the circuit as much as possible
    Sindices, Ssymbols_to_values, Sindex_to_symbols = Simp.reduce_circuit(M_indices, M_symbols_to_values, M_idx_to_symbols)

    ## compute the energy of the mutated-simplified circuit [Note 1]
    MSenergy, MSsymbols_to_values, _ = vqe_handler.vqe(Sindices, symbols_to_values=Ssymbols_to_values, parameter_perturbation_wall=np.pi/10.)


    if evaluator.accept_energy(MSenergy):
        #delete as many 1-qubit gates as possible, as long as the energy doesn't go up (we allow %1 increments per iteration)
        indexed_circuit, symbol_to_value, index_to_symbols = Sindices, MSsymbols_to_values, Sindex_to_symbols

        cnt=0
        reduced=True
        lmax=len(indexed_circuit)
        while reduced and cnt < lmax:
            indexed_circuit, symbol_to_value, index_to_symbols, energy, reduced = unitary_killer.unitary_slaughter(indexed_circuit, symbol_to_value, index_to_symbols, reference_energy = MSenergy)
            indexed_circuit, symbol_to_value, index_to_symbols = Simp.reduce_circuit(indexed_circuit, symbol_to_value, index_to_symbols)
            cnt+=1
        print("Accepted circuit! Actually I reduced it from {} to {}. With this, energy increased {}".format(len(Sindices), len(indexed_circuit), MSenergy-energy))
        relevant=True

    evaluator.add_step(indexed_circuit, symbol_to_value, energy, relevant=relevant)
    to_print=f"iteration: {iteration} \n"\
            f"best energy {evaluator.lowest_energy} \n"\
            f"current energy {energy}\n"\
            f"Number of params {vqe_handler.count_params(indexed_circuit)}\n"\
            f"Number of CNOTs {vqe_handler.count_cnots(indexed_circuit)}\n"
    print(to_print)
    evaluator.save_dicts_and_displaying()
# Out:
# Accepted circuit! Actually I reduced it from 16 to 14. With this, energy increased -0.000232696533203125
# iteration: 0
# best energy -4.836162567138672
# current energy -4.836162567138672
# Number of params 11
# Number of CNOTs 3
#
# Accepted circuit! Actually I reduced it from 20 to 14. With this, energy increased -0.01478433609008789
# iteration: 1
# best energy -4.836162567138672
# current energy -4.8216118812561035
# Number of params 11
# Number of CNOTs 3
#
# Accepted circuit! Actually I reduced it from 21 to 19. With this, energy increased -0.032878875732421875
# iteration: 2
# best energy -4.836162567138672
# current energy -4.811286449432373
# Number of params 14
# Number of CNOTs 5
#
# Accepted circuit! Actually I reduced it from 33 to 31. With this, energy increased -0.020131587982177734
# iteration: 3
# best energy -4.867609977722168
# current energy -4.867609977722168
# Number of params 22
# Number of CNOTs 9
#
# Accepted circuit! Actually I reduced it from 48 to 42. With this, energy increased -0.061322689056396484
# iteration: 4
# best energy -5.164930820465088
# current energy -5.164930820465088
# Number of params 29
# Number of CNOTs 13

# %%
problem_config={"problem":"TFIM", "J":1.0, "g":1.0}

vqe_handler = VQE(n_qubits=4, epochs=2000, 
                  verbose=1,problem_config=problem_config,
                  optimizer="adam", lr=0.01)


dict_evaluator={"n_qubits":4,"problem_config":problem_config, "specific_name":"TFIM/{}Q - J {} g {}".format(vqe_handler.n_qubits, problem_config["J"], problem_config["g"])}

evaluator = Evaluator(dict_evaluator, path="examples_repository/", acceptance_percentage=1e-3, 
                      reduce_acceptance_percentage=True, loading=True,)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-950ee83b9546> in <module>
#       9
#      10 evaluator = Evaluator(dict_evaluator, path="examples_repository/", acceptance_percentage=1e-3,
# ---> 11                       reduce_acceptance_percentage=True, loading=True)
#
# ~/qvans/utilities/evaluator.py in __init__(self, args, info, loading, acceptance_percentage, reduce_acceptance_percentage, accuracy_to_end, nrun_load, path)
#      76             else:
#      77                 self.identifier = "{}/{}".format(args["problem_config"]["problem"], args["specific_folder_name"])
# ---> 78             self.load(args_load,nrun=nrun_load, load_displaying = args_load["load_displaying"]) #this is because i changed this abit...
#      79
#      80                 #if args_load["specific_name"] is None:
#
# ~/qvans/utilities/evaluator.py in load(self, args, nrun, load_displaying)
#     137     def load(self,args, nrun=0, load_displaying=False):
#     138         name_folder = self.path+self.identifier+"/run_{}".format(nrun)
# --> 139         self.load_dicts_and_displaying(name_folder, load_displaying=load_displaying)
#     140         return
#     141
#
# ~/qvans/utilities/evaluator.py in load_dicts_and_displaying(self, folder, load_displaying)
#     162
#     163     def load_dicts_and_displaying(self,folder, load_displaying=False):
# --> 164         with open(folder+"/raw_history.pkl" ,"rb") as h:
#     165             self.raw_history = pickle.load(h)
#     166         with open(folder+"/evolution.pkl", "rb") as hh:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'examples_repository/TFIM/4Qbits_g1.0J1.0_TFIM/4Q - J 1.0 g 1.0/run_0/raw_history.pkl'

# %%
circuits = [list(evaluator.raw_history.values())[k][0] for k in range(len(evaluator.raw_history.keys()))]
energies = [list(evaluator.raw_history.values())[k][1] for k in range(len(evaluator.raw_history.keys()))]

# %%
import base64

# %%
import os 
os.makedirs("gifs",exist_ok=True)
for ind,k in enumerate(circuits):
    k.save_qasm("gifs/{}".format(ind))

# %%
k.

# %% [markdown]
# As expected, this initial circuit is not complex enough (since it prepares only separable states).

# %% [markdown]
# ### Identity insertion

# %% [markdown]
# Let us now look how VANs adds new block of gates

# %%
from utilities.idinserter import IdInserter
iid = IdInserter(n_qubits=vqe_handler.n_qubits, selector_temperature = 10.0)

# %% [markdown]
# First, we can choose the probability of appending more than one identity resolution, via the <i>rate_iids_per_step</i> option (essentially this parameter controls the temperature of an exponentially decaying distribution that rules the probability of adding N gates).

# %%
import PIL
from PIL import ImageFont
from PIL import Image
from PIL import ImageDraw

def text2png(text, fullpath, color = "#000", bgcolor = "#FFF", fontfullpath = None, fontsize = 13, leftpadding = 3, rightpadding = 3, width = 200):
	REPLACEMENT_CHARACTER = u'\uFFFD'
	NEWLINE_REPLACEMENT_STRING = ' ' + REPLACEMENT_CHARACTER + ' '

	#prepare linkback
	linkback = "created via http://ourdomain.com"
	fontlinkback = ImageFont.truetype('font.ttf', 8)
	linkbackx = fontlinkback.getsize(linkback)[0]
	linkback_height = fontlinkback.getsize(linkback)[1]
	#end of linkback

	font = ImageFont.load_default() if fontfullpath == None else ImageFont.truetype(fontfullpath, fontsize)
	text = text.replace('\n', NEWLINE_REPLACEMENT_STRING)

	lines = []
	line = u""

	for word in text.split():
		print word
		if word == REPLACEMENT_CHARACTER: #give a blank line
			lines.append( line[1:] ) #slice the white space in the begining of the line
			line = u""
			lines.append( u"" ) #the blank line
		elif font.getsize( line + ' ' + word )[0] <= (width - rightpadding - leftpadding):
			line += ' ' + word
		else: #start a new line
			lines.append( line[1:] ) #slice the white space in the begining of the line
			line = u""

			#TODO: handle too long words at this point
			line += ' ' + word #for now, assume no word alone can exceed the line width

	if len(line) != 0:
		lines.append( line[1:] ) #add the last line

	line_height = font.getsize(text)[1]
	img_height = line_height * (len(lines) + 1)

	img = Image.new("RGBA", (width, img_height), bgcolor)
	draw = ImageDraw.Draw(img)

	y = 0
	for line in lines:
		draw.text( (leftpadding, y), line, color, font=font)
		y += line_height

	# add linkback at the bottom
	draw.text( (width - linkbackx, img_height - linkback_height), linkback, color, font=fontlinkback)

	img.save(fullpath)

#show time
text2png(u"This is\na\ntest şğıöç zaa xd ve lorem hipster", 'test.png', fontfullpath = "font.ttf")

# %%
print("*"*100)
print("Initial circuit ")
display(vqe_handler.give_unitary(indexed_circuit,resolver))
print("\n\n")
mutations = {}
rates_iid_per_step = [0.0, 1.0, 10.0]
for ind, rate in enumerate(rates_iid_per_step):
    print("Adding identiies with rate_iid_per_step {}".format(rate))
    mutations[ind]= iid.place_identities(indexed_circuit, resolver, rate_iids_per_step=rate)
    display(vqe_handler.give_unitary(mutations[ind][0],mutations[ind][1]))
    print("\n")
# Out:
# ****************************************************************************************************
# Initial circuit
# (0, 0): ───Rx(0)────
#
# (0, 1): ───Rx(0)────
#
# (0, 2): ───Rx(2π)───
#
# (0, 3): ───Rx(2π)───
# Adding identiies with rate_iid_per_step 0.0
# (0, 0): ───Rx(0)─────────────────────────────────────────────────────
#
# (0, 1): ───Rx(0)────@───Rz(-0.032π)───Rx(-0.032π)───Rz(0.032π)───@───
#                     │                                            │
# (0, 2): ───Rx(2π)───X───Rx(-0.032π)───Rz(-0.032π)───Rx(0.032π)───X───
#
# (0, 3): ───Rx(2π)────────────────────────────────────────────────────
# Adding identiies with rate_iid_per_step 1.0
#                     ┌────────────┐
# (0, 0): ───Rx(0)────────────────X───────────────────────────────X────────────Rx(0.032π)───Rz(0.032π)───Rx(0.032π)───X───Rx(0.032π)───Rz(-0.032π)───Rx(0.032π)───X────────────
#                                 │                               │                                                   │                                           │
# (0, 1): ───Rx(0)─────Rz(-0.032π)┼────Rx(0.032π)───Rz(0.032π)────┼───────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────
#                                 │                               │                                                   │                                           │
# (0, 2): ───Rx(2π)────Rz(0.032π)─┼────Rx(0.032π)───Rz(-0.032π)───@────────────Rz(0.032π)───Rx(0.032π)───Rz(0.032π)───@───────────────────────────────────────────┼────────────
#                                 │                                                                                                                               │
# (0, 3): ────────────────────────@────Rz(0.032π)───Rx(-0.032π)───Rz(0.032π)──────────────────────────────────────────────────────────────────────────────────────@───Rx(2π)───
#                     └────────────┘
# Adding identiies with rate_iid_per_step 10.0
# (0, 0): ───Rx(0)────X───Rx(-0.032π)───Rz(0.032π)───Rx(-0.032π)───X───
#                     │                                            │
# (0, 1): ───Rx(0)────┼────────────────────────────────────────────┼───
#                     │                                            │
# (0, 2): ───Rx(2π)───@───Rz(-0.032π)───Rx(0.032π)───Rz(-0.032π)───@───
#
# (0, 3): ───Rx(2π)────────────────────────────────────────────────────

# %% [markdown]
# Moreover, the IIdInserter "weights" how many qubits are affected by rotations/CNOTs, giving more (or less) priority to each qubit, at the moment of adding new gates.
#
# Let us consider an example where a circuit has more gates acting on the first two qubits. For different values of the selector_temperature, IIdInserter will spread new gates more uniformly among the circuit, or won't care about gate distribution.
#
# <u> Comment</u>: The intuition here is that for a problem complex enough, there should at least be some gates acting at each qubit, and some correlations present between different qubits; thus this mechanism prevents the algorithm to get stucked in circuits that have no gates acting on the different subsystems

# %%
ind_circuit = [vqe_handler.number_of_cnots + vqe_handler.n_qubits + k for k in range(vqe_handler.n_qubits)]
more_gates = [vqe_handler.number_of_cnots + k for k in range(int(vqe_handler.n_qubits/2))]
even_more_gates = [vqe_handler.number_of_cnots + vqe_handler.n_qubits + k for k in range(int(vqe_handler.n_qubits/2))]

for k in range(3):
    for ii in more_gates:
        ind_circuit.append(ii)
    for ii in even_more_gates:
        ind_circuit.append(ii)
    for ii in [0]:
        ind_circuit.append(ii)

circuit, symbols, ind_to_symbol = vqe_handler.give_circuit(ind_circuit)
random_resolver = {s:r for s,r in zip(symbols, np.random.randn(len(symbols)))}
print("Initial circuit")
display(cirq.resolve_parameters(circuit,random_resolver))
print("\n\n")

### Note that T=0.0 will be random, thus you might run this cell many times.
for T in [0.0, 100.0]:
    print("Add single identity with selector_temperature {}".format(T))
    iid = IdInserter(n_qubits=vqe_handler.n_qubits, selector_temperature = T)
    identity_added= iid.place_identities(ind_circuit, random_resolver, rate_iids_per_step=0.0)
    display(vqe_handler.give_unitary(identity_added[0],identity_added[1]))
    print("\n \n")
# Out:
# Initial circuit
# (0, 0): ───Rx(-0.205π)───Rz(0.077π)───Rx(0.045π)────@───Rz(0.087π)───Rx(0.257π)────@───Rz(-0.129π)───Rx(0.144π)────@───
#                                                     │                              │                               │
# (0, 1): ───Rx(-0.124π)───Rz(0.135π)───Rx(-0.024π)───X───Rz(0.016π)───Rx(-0.162π)───X───Rz(0.099π)────Rx(-0.399π)───X───
#
# (0, 2): ───Rx(-0.195π)─────────────────────────────────────────────────────────────────────────────────────────────────
#
# (0, 3): ───Rx(-0.382π)─────────────────────────────────────────────────────────────────────────────────────────────────
# Add single identity with selector_temperature 0.0
#                                                                                        ┌───────────┐
# (0, 0): ───Rx(-0.205π)───Rz(0.077π)───Rx(0.045π)────@───Rz(0.087π)───Rx(0.257π)────@────@──────────────Rz(0.032π)────Rx(-0.032π)───Rz(0.032π)───@───Rz(-0.129π)───Rx(0.144π)───@───
#                                                     │                              │    │                                                       │                              │
# (0, 1): ───Rx(-0.124π)───Rz(0.135π)───Rx(-0.024π)───X───Rz(0.016π)───Rx(-0.162π)───X────┼Rz(0.099π)────Rx(-0.399π)──────────────────────────────┼──────────────────────────────X───
#                                                                                         │                                                       │
# (0, 2): ───Rx(-0.195π)──────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────
#                                                                                         │                                                       │
# (0, 3): ───Rx(-0.382π)──────────────────────────────────────────────────────────────────X──────────────Rx(0.032π)────Rz(-0.032π)───Rx(0.032π)───X──────────────────────────────────
#                                                                                        └───────────┘
#
#
# Add single identity with selector_temperature 100.0
# (0, 0): ───Rx(-0.205π)───Rz(0.077π)───Rx(0.045π)────@─────────────Rz(0.087π)───Rx(0.257π)────@───Rz(-0.129π)───Rx(0.144π)────@───
#                                                     │                                        │                               │
# (0, 1): ───Rx(-0.124π)───Rz(0.135π)───Rx(-0.024π)───X─────────────Rz(0.016π)───Rx(-0.162π)───X───Rz(0.099π)────Rx(-0.399π)───X───
#
# (0, 2): ───Rx(-0.195π)───Rz(0.032π)───Rx(0.032π)────Rz(-0.032π)──────────────────────────────────────────────────────────────────
#
# (0, 3): ───Rx(-0.382π)───────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ### Simplifying the circuit
#
# The next method we review is the Simplifier. Here, the circuit is reduced to an equivalent one (i.e. energy-preserving transformations), according to specific rules (check paper for details).
#
# Let us inspect how this works for the TFIM, on some circuit having many redundancies.

# %%
ind_circuit = [vqe_handler.number_of_cnots + k for k in range(vqe_handler.n_qubits)]
more_gates = [vqe_handler.number_of_cnots + vqe_handler.n_qubits + k for k in range(int(vqe_handler.n_qubits/2))]
even_more_gates = [vqe_handler.number_of_cnots + vqe_handler.n_qubits + k for k in range(int(vqe_handler.n_qubits/2))]
        
for ii in ind_circuit[:]:
    ind_circuit.append(ii)
    ind_circuit.append(ii)

for ii in more_gates:
    ind_circuit.append(ii)
    ind_circuit.append(ii)
for k in range(vqe_handler.number_of_cnots):
    ind_circuit.append(k)
    ind_circuit.append(k)

    
circuit, symbols, ind_to_symbol = vqe_handler.give_circuit(ind_circuit)
random_resolver = {s:r for s,r in zip(symbols, np.random.randn(len(symbols)))}
print("Initial redundant circuit")
display(cirq.resolve_parameters(circuit,random_resolver))
print("\n\n")



Simp = Simplifier(n_qubits=len(vqe_handler.qubits))
Sindices, Ssymbols_to_values, Sindex_to_symbols = Simp.reduce_circuit(ind_circuit, random_resolver, ind_to_symbol)


reduced_state = cirq.unitary(cirq.resolve_parameters(vqe_handler.give_circuit(Sindices)[0], Ssymbols_to_values))[:,0]
initial_state = cirq.unitary(cirq.resolve_parameters(vqe_handler.give_circuit(ind_circuit)[0], random_resolver))[:,0]


print("REDUCED CIRCUIT: \n")
Scircuit, Ssymbols, Sind_to_symbol = vqe_handler.give_circuit(Sindices)
display(cirq.resolve_parameters(Scircuit,Ssymbols_to_values))
print("\n\n")


print("INITIAL ENERGY: {}".format(overlap(initial_state,np.dot(H,initial_state))))
print("FINAL ENERGY: {}".format(overlap(reduced_state,np.dot(H,reduced_state))))
# Out:
# Initial redundant circuit
#                                                                                                                          ┌──┐   ┌──┐
# (0, 0): ───Rz(-0.119π)───Rz(-0.231π)───Rz(-0.536π)───Rx(0.284π)────Rx(0.014π)────@───@───@───@───@───@───X───X─────────────X──────X────────────────────X───X───────────────────
#                                                                                  │   │   │   │   │   │   │   │             │      │                    │   │
# (0, 1): ───Rz(-0.418π)───Rz(-0.705π)───Rz(0.224π)────Rx(-0.169π)───Rx(-0.179π)───X───X───┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X───X───────────
#                                                                                          │   │   │   │           │   │    ││     ││    │   │           │   │   │   │
# (0, 2): ───Rz(-0.254π)───Rz(0.375π)────Rz(-0.136π)───────────────────────────────────────X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼───┼───X───X───
#                                                                                                  │   │                    │      │             │   │   │   │   │   │   │   │
# (0, 3): ───Rz(-0.119π)───Rz(-0.198π)───Rz(0.484π)────────────────────────────────────────────────X───X────────────────────X──────X─────────────X───X───@───@───@───@───@───@───
#                                                                                                                          └──┘   └──┘
# REDUCED CIRCUIT:
# (0, 0): ───Rx(0.298π)────
#
# (0, 1): ───Rx(-0.348π)───
#
# (0, 2): ───Rx(0)─────────
#
# (0, 3): ───Rx(0)─────────
# INITIAL ENERGY: (-3.0519328224171423+0j)
# FINAL ENERGY: (-3.051932822417141+0j)

# %% [markdown]
# ### Unitary Killer
#
# Let us now move to inspect how VANs simplify the circuit even further. Essentially, we delete gates whose presence in the circuit does not contribute to reducing the energy (too much). For example, if rotations compile to identity, they should not contribute and are likely to be removed.
#
# The parameter acccept_wall ($\beta$) the probability $e^{-\beta \frac{\delta E}{E_i}}$ at which, if $\delta E >0$, the change is accepted (i.e. energy increases but we still admit this simplification). Feel free to play with the acceptance_wall parameter to see the effect!

# %%
x=np.linspace(0,.1,100)
b=10.
y = np.exp(-b*x)

from bokeh.layouts import column, row
from bokeh.models import CustomJS, Slider
from bokeh.plotting import ColumnDataSource, figure, output_notebook, show

output_notebook()
source = ColumnDataSource(data=dict(x=x, y=y))

plot = figure(y_range=(0, 1), plot_width=400, plot_height=400,x_axis_label="Relative Energy shift", y_axis_label="Acceptance probability")
plot.xgrid.grid_line_color = None
plot.ygrid.grid_line_color = None
plot.line('x', 'y', source=source, line_width=5, line_alpha=0.9,color="red")

b_slider = Slider(start=0, end=1000, value=b, step=10, title='Acceptance wall')

callback = CustomJS(args=dict(source=source, b_slider=b_slider),
                    code="""
    const data = source.data;
    const B = b_slider.value;
    const x = data['x']
    const y = data['y']
    for (var i = 0; i < x.length; i++) {
        y[i] = Math.exp(-B*x[i]);
    }
    source.change.emit();
""")
b_slider.js_on_change('value', callback)

layout = row(
    plot,
    column(b_slider),
)


show(layout)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1989">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6f6394b6-5e45-4902-8af8-09ab9225233b" data-root-id="2030"></div>

# %% [markdown]
# Let's implement this mechanism for the circuit we have obtained by appending an identity resolution to the separable qubit

# %%
indexed_circuit_1, resolver1, positions1 = mutations[1]
display(vqe_handler.give_unitary(indexed_circuit_1, resolver1))
# Out:
#                     ┌────────────┐
# (0, 0): ───Rx(0)────────────────X───────────────────────────────X────────────Rx(0.032π)───Rz(0.032π)───Rx(0.032π)───X───Rx(0.032π)───Rz(-0.032π)───Rx(0.032π)───X────────────
#                                 │                               │                                                   │                                           │
# (0, 1): ───Rx(0)─────Rz(-0.032π)┼────Rx(0.032π)───Rz(0.032π)────┼───────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────
#                                 │                               │                                                   │                                           │
# (0, 2): ───Rx(2π)────Rz(0.032π)─┼────Rx(0.032π)───Rz(-0.032π)───@────────────Rz(0.032π)───Rx(0.032π)───Rz(0.032π)───@───────────────────────────────────────────┼────────────
#                                 │                                                                                                                               │
# (0, 3): ────────────────────────@────Rz(0.032π)───Rx(-0.032π)───Rz(0.032π)──────────────────────────────────────────────────────────────────────────────────────@───Rx(2π)───
#                     └────────────┘

# %%
energy2, resolver2, pos2 = vqe_handler.vqe(indexed_circuit_1, resolver1)
# Out:
# Epoch 1/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.8819 - lr: 0.0100 - grad_norm: 0.9156
# Epoch 2/10000
# 1/1 [==============================] - 0s 970us/step - energy: -3.9092 - lr: 0.0100 - grad_norm: 0.7108
# Epoch 3/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9328 - lr: 0.0100 - grad_norm: 0.5308
# Epoch 4/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9524 - lr: 0.0100 - grad_norm: 0.3772
# Epoch 5/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9682 - lr: 0.0100 - grad_norm: 0.2513
# Epoch 6/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9802 - lr: 0.0100 - grad_norm: 0.1536
# Epoch 7/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9887 - lr: 0.0100 - grad_norm: 0.0833
# Epoch 8/10000
# 1/1 [==============================] - 0s 4ms/step - energy: -3.9941 - lr: 0.0100 - grad_norm: 0.0382
# Epoch 9/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9969 - lr: 0.0100 - grad_norm: 0.0150
# Epoch 10/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9978 - lr: 0.0100 - grad_norm: 0.0092
# Epoch 11/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9972 - lr: 0.0100 - grad_norm: 0.0160
# Epoch 12/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9959 - lr: 0.0100 - grad_norm: 0.0304
# Epoch 13/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9942 - lr: 0.0100 - grad_norm: 0.0479
# Epoch 14/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9925 - lr: 0.0100 - grad_norm: 0.0645
# Epoch 15/10000
# 1/1 [==============================] - 0s 4ms/step - energy: -3.9912 - lr: 0.0100 - grad_norm: 0.0775
# Epoch 16/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9903 - lr: 0.0100 - grad_norm: 0.0853
# Epoch 17/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9901 - lr: 0.0100 - grad_norm: 0.0875
# Epoch 18/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9903 - lr: 0.0100 - grad_norm: 0.0845
# Epoch 19/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9910 - lr: 0.0100 - grad_norm: 0.0771
# Epoch 20/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9920 - lr: 0.0100 - grad_norm: 0.0667
# Epoch 21/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9932 - lr: 0.0100 - grad_norm: 0.0547
# Epoch 22/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9945 - lr: 0.0100 - grad_norm: 0.0422
# Epoch 23/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9957 - lr: 0.0100 - grad_norm: 0.0305
# Epoch 24/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9969 - lr: 0.0100 - grad_norm: 0.0204
# Epoch 25/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9978 - lr: 0.0100 - grad_norm: 0.0126
# Epoch 26/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9985 - lr: 0.0100 - grad_norm: 0.0072
# Epoch 27/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9990 - lr: 0.0100 - grad_norm: 0.0043
# Epoch 28/10000
# 1/1 [==============================] - 0s 994us/step - energy: -3.9993 - lr: 0.0100 - grad_norm: 0.0037
# Epoch 29/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9993 - lr: 0.0100 - grad_norm: 0.0047
# Epoch 30/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9992 - lr: 0.0100 - grad_norm: 0.0069
# Epoch 31/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9990 - lr: 0.0100 - grad_norm: 0.0094
# Epoch 32/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9988 - lr: 0.0100 - grad_norm: 0.0119
# Epoch 33/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -3.9986 - lr: 0.0100 - grad_norm: 0.0137
# Epoch 34/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9985 - lr: 0.0100 - grad_norm: 0.0146
# Epoch 35/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -3.9985 - lr: 0.0100 - grad_norm: 0.0145
# Epoch 36/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9985 - lr: 0.0100 - grad_norm: 0.0135
# Epoch 37/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -3.9987 - lr: 0.0100 - grad_norm: 0.0117
# Epoch 38/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9989 - lr: 0.0100 - grad_norm: 0.0094
# Epoch 39/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9991 - lr: 0.0100 - grad_norm: 0.0070
# Epoch 40/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9994 - lr: 0.0100 - grad_norm: 0.0048
# Epoch 41/10000
# 1/1 [==============================] - 0s 883us/step - energy: -3.9996 - lr: 0.0100 - grad_norm: 0.0030
# Epoch 42/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9997 - lr: 0.0100 - grad_norm: 0.0018
# Epoch 43/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9998 - lr: 0.0100 - grad_norm: 0.0011
# Epoch 44/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9999 - lr: 0.0100 - grad_norm: 0.0010
# Epoch 45/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9999 - lr: 0.0100 - grad_norm: 0.0013
# Epoch 46/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9999 - lr: 0.0100 - grad_norm: 0.0018
# Epoch 47/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9998 - lr: 0.0100 - grad_norm: 0.0024
# Epoch 48/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9998 - lr: 0.0100 - grad_norm: 0.0028
# Epoch 49/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9998 - lr: 0.0100 - grad_norm: 0.0031
# Epoch 50/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9998 - lr: 0.0100 - grad_norm: 0.0031
# Epoch 51/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -3.9998 - lr: 0.0100 - grad_norm: 0.0028
# Epoch 52/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9999 - lr: 0.0100 - grad_norm: 0.0024
# Epoch 53/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -3.9999 - lr: 0.0100 - grad_norm: 0.0019
# Epoch 54/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0000 - lr: 0.0100 - grad_norm: 0.0013
# Epoch 55/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0001 - lr: 0.0100 - grad_norm: 8.5116e-04
# Epoch 56/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0001 - lr: 0.0100 - grad_norm: 5.0990e-04
# Epoch 57/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0001 - lr: 0.0100 - grad_norm: 3.2035e-04
# Epoch 58/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0002 - lr: 0.0100 - grad_norm: 2.8039e-04
# Epoch 59/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0002 - lr: 0.0100 - grad_norm: 3.5589e-04
# Epoch 60/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0002 - lr: 0.0100 - grad_norm: 4.9842e-04
# Epoch 61/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0002 - lr: 0.0100 - grad_norm: 6.6065e-04
# Epoch 62/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0002 - lr: 0.0100 - grad_norm: 7.9358e-04
# Epoch 63/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0002 - lr: 0.0100 - grad_norm: 8.7509e-04
# Epoch 64/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0002 - lr: 0.0100 - grad_norm: 8.8858e-04
# Epoch 65/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0003 - lr: 0.0100 - grad_norm: 8.3580e-04
# Epoch 66/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0003 - lr: 0.0100 - grad_norm: 7.3127e-04
# Epoch 67/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0004 - lr: 0.0100 - grad_norm: 6.0550e-04
# Epoch 68/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0004 - lr: 0.0100 - grad_norm: 4.7143e-04
# Epoch 69/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.0005 - lr: 0.0100 - grad_norm: 3.6124e-04
# Epoch 70/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0005 - lr: 0.0100 - grad_norm: 2.8094e-04
# Epoch 71/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0006 - lr: 0.0100 - grad_norm: 2.3975e-04
# Epoch 72/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0006 - lr: 0.0100 - grad_norm: 2.3196e-04
# Epoch 73/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0007 - lr: 0.0100 - grad_norm: 2.5189e-04
# Epoch 74/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0007 - lr: 0.0100 - grad_norm: 2.8311e-04
# Epoch 75/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0008 - lr: 0.0100 - grad_norm: 3.2118e-04
# Epoch 76/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0009 - lr: 0.0100 - grad_norm: 3.5523e-04
# Epoch 77/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0010 - lr: 0.0100 - grad_norm: 3.8787e-04
# Epoch 78/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0012 - lr: 0.0100 - grad_norm: 4.2640e-04
# Epoch 79/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0013 - lr: 0.0100 - grad_norm: 4.8060e-04
# Epoch 80/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0015 - lr: 0.0100 - grad_norm: 5.6933e-04
# Epoch 81/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0017 - lr: 0.0100 - grad_norm: 7.1004e-04
# Epoch 82/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.0019 - lr: 0.0100 - grad_norm: 9.2410e-04
# Epoch 83/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0022 - lr: 0.0100 - grad_norm: 0.0012
# Epoch 84/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0026 - lr: 0.0100 - grad_norm: 0.0016
# Epoch 85/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0029 - lr: 0.0100 - grad_norm: 0.0022
# Epoch 86/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0034 - lr: 0.0100 - grad_norm: 0.0028
# Epoch 87/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0039 - lr: 0.0100 - grad_norm: 0.0036
# Epoch 88/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0046 - lr: 0.0100 - grad_norm: 0.0046
# Epoch 89/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.0054 - lr: 0.0100 - grad_norm: 0.0057
# Epoch 90/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0063 - lr: 0.0100 - grad_norm: 0.0070
# Epoch 91/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0074 - lr: 0.0100 - grad_norm: 0.0087
# Epoch 92/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0088 - lr: 0.0100 - grad_norm: 0.0106
# Epoch 93/10000
# 1/1 [==============================] - 0s 883us/step - energy: -4.0104 - lr: 0.0100 - grad_norm: 0.0129
# Epoch 94/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0123 - lr: 0.0100 - grad_norm: 0.0156
# Epoch 95/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0146 - lr: 0.0100 - grad_norm: 0.0188
# Epoch 96/10000
# 1/1 [==============================] - 0s 811us/step - energy: -4.0173 - lr: 0.0100 - grad_norm: 0.0225
# Epoch 97/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0204 - lr: 0.0100 - grad_norm: 0.0265
# Epoch 98/10000
# 1/1 [==============================] - 0s 916us/step - energy: -4.0241 - lr: 0.0100 - grad_norm: 0.0307
# Epoch 99/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0283 - lr: 0.0100 - grad_norm: 0.0351
# Epoch 100/10000
# 1/1 [==============================] - 0s 959us/step - energy: -4.0331 - lr: 0.0100 - grad_norm: 0.0394
# Epoch 101/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0384 - lr: 0.0100 - grad_norm: 0.0434
# Epoch 102/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0442 - lr: 0.0100 - grad_norm: 0.0468
# Epoch 103/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0505 - lr: 0.0100 - grad_norm: 0.0492
# Epoch 104/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0571 - lr: 0.0100 - grad_norm: 0.0505
# Epoch 105/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0640 - lr: 0.0100 - grad_norm: 0.0505
# Epoch 106/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.0710 - lr: 0.0100 - grad_norm: 0.0493
# Epoch 107/10000
# 1/1 [==============================] - 0s 851us/step - energy: -4.0781 - lr: 0.0100 - grad_norm: 0.0467
# Epoch 108/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0852 - lr: 0.0100 - grad_norm: 0.0428
# Epoch 109/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0922 - lr: 0.0100 - grad_norm: 0.0380
# Epoch 110/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.0990 - lr: 0.0100 - grad_norm: 0.0325
# Epoch 111/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.1054 - lr: 0.0100 - grad_norm: 0.0269
# Epoch 112/10000
# 1/1 [==============================] - 0s 947us/step - energy: -4.1113 - lr: 0.0100 - grad_norm: 0.0217
# Epoch 113/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.1166 - lr: 0.0100 - grad_norm: 0.0174
# Epoch 114/10000
# 1/1 [==============================] - 0s 993us/step - energy: -4.1213 - lr: 0.0100 - grad_norm: 0.0146
# Epoch 115/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.1253 - lr: 0.0100 - grad_norm: 0.0136
# Epoch 116/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.1287 - lr: 0.0100 - grad_norm: 0.0145
# Epoch 117/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.1317 - lr: 0.0100 - grad_norm: 0.0169
# Epoch 118/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.1344 - lr: 0.0100 - grad_norm: 0.0202
# Epoch 119/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.1370 - lr: 0.0100 - grad_norm: 0.0240
# Epoch 120/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.1398 - lr: 0.0100 - grad_norm: 0.0275
# Epoch 121/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.1428 - lr: 0.0100 - grad_norm: 0.0302
# Epoch 122/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.1461 - lr: 0.0100 - grad_norm: 0.0322
# Epoch 123/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.1498 - lr: 0.0100 - grad_norm: 0.0337
# Epoch 124/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.1538 - lr: 0.0100 - grad_norm: 0.0349
# Epoch 125/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.1582 - lr: 0.0100 - grad_norm: 0.0365
# Epoch 126/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.1630 - lr: 0.0100 - grad_norm: 0.0390
# Epoch 127/10000
# 1/1 [==============================] - 0s 885us/step - energy: -4.1681 - lr: 0.0100 - grad_norm: 0.0427
# Epoch 128/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.1737 - lr: 0.0100 - grad_norm: 0.0480
# Epoch 129/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.1798 - lr: 0.0100 - grad_norm: 0.0551
# Epoch 130/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.1864 - lr: 0.0100 - grad_norm: 0.0638
# Epoch 131/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.1937 - lr: 0.0100 - grad_norm: 0.0740
# Epoch 132/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.2017 - lr: 0.0100 - grad_norm: 0.0854
# Epoch 133/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.2104 - lr: 0.0100 - grad_norm: 0.0977
# Epoch 134/10000
# 1/1 [==============================] - 0s 874us/step - energy: -4.2200 - lr: 0.0100 - grad_norm: 0.1107
# Epoch 135/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.2304 - lr: 0.0100 - grad_norm: 0.1242
# Epoch 136/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.2417 - lr: 0.0100 - grad_norm: 0.1380
# Epoch 137/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.2538 - lr: 0.0100 - grad_norm: 0.1522
# Epoch 138/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.2667 - lr: 0.0100 - grad_norm: 0.1671
# Epoch 139/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.2805 - lr: 0.0100 - grad_norm: 0.1826
# Epoch 140/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.2952 - lr: 0.0100 - grad_norm: 0.1990
# Epoch 141/10000
# 1/1 [==============================] - 0s 847us/step - energy: -4.3107 - lr: 0.0100 - grad_norm: 0.2161
# Epoch 142/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.3270 - lr: 0.0100 - grad_norm: 0.2338
# Epoch 143/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.3441 - lr: 0.0100 - grad_norm: 0.2519
# Epoch 144/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.3621 - lr: 0.0100 - grad_norm: 0.2700
# Epoch 145/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.3809 - lr: 0.0100 - grad_norm: 0.2879
# Epoch 146/10000
# 1/1 [==============================] - 0s 991us/step - energy: -4.4003 - lr: 0.0100 - grad_norm: 0.3049
# Epoch 147/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.4204 - lr: 0.0100 - grad_norm: 0.3208
# Epoch 148/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.4409 - lr: 0.0100 - grad_norm: 0.3350
# Epoch 149/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.4618 - lr: 0.0100 - grad_norm: 0.3474
# Epoch 150/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.4829 - lr: 0.0100 - grad_norm: 0.3572
# Epoch 151/10000
# 1/1 [==============================] - 0s 973us/step - energy: -4.5041 - lr: 0.0100 - grad_norm: 0.3643
# Epoch 152/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.5252 - lr: 0.0100 - grad_norm: 0.3684
# Epoch 153/10000
# 1/1 [==============================] - 0s 924us/step - energy: -4.5461 - lr: 0.0100 - grad_norm: 0.3685
# Epoch 154/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.5668 - lr: 0.0100 - grad_norm: 0.3654
# Epoch 155/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.5872 - lr: 0.0100 - grad_norm: 0.3577
# Epoch 156/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.6071 - lr: 0.0100 - grad_norm: 0.3468
# Epoch 157/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.6265 - lr: 0.0100 - grad_norm: 0.3311
# Epoch 158/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.6452 - lr: 0.0100 - grad_norm: 0.3130
# Epoch 159/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.6631 - lr: 0.0100 - grad_norm: 0.2915
# Epoch 160/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.6801 - lr: 0.0100 - grad_norm: 0.2678
# Epoch 161/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.6960 - lr: 0.0100 - grad_norm: 0.2434
# Epoch 162/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.7109 - lr: 0.0100 - grad_norm: 0.2176
# Epoch 163/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.7246 - lr: 0.0100 - grad_norm: 0.1924
# Epoch 164/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.7371 - lr: 0.0100 - grad_norm: 0.1681
# Epoch 165/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.7484 - lr: 0.0100 - grad_norm: 0.1447
# Epoch 166/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.7585 - lr: 0.0100 - grad_norm: 0.1233
# Epoch 167/10000
# 1/1 [==============================] - 0s 898us/step - energy: -4.7674 - lr: 0.0100 - grad_norm: 0.1035
# Epoch 168/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.7752 - lr: 0.0100 - grad_norm: 0.0858
# Epoch 169/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.7820 - lr: 0.0100 - grad_norm: 0.0704
# Epoch 170/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.7877 - lr: 0.0100 - grad_norm: 0.0570
# Epoch 171/10000
# 1/1 [==============================] - 0s 908us/step - energy: -4.7925 - lr: 0.0100 - grad_norm: 0.0458
# Epoch 172/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.7964 - lr: 0.0100 - grad_norm: 0.0367
# Epoch 173/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.7996 - lr: 0.0100 - grad_norm: 0.0296
# Epoch 174/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8021 - lr: 0.0100 - grad_norm: 0.0243
# Epoch 175/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8041 - lr: 0.0100 - grad_norm: 0.0206
# Epoch 176/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8056 - lr: 0.0100 - grad_norm: 0.0182
# Epoch 177/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8068 - lr: 0.0100 - grad_norm: 0.0169
# Epoch 178/10000
# 1/1 [==============================] - 0s 922us/step - energy: -4.8077 - lr: 0.0100 - grad_norm: 0.0165
# Epoch 179/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8084 - lr: 0.0100 - grad_norm: 0.0167
# Epoch 180/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8091 - lr: 0.0100 - grad_norm: 0.0173
# Epoch 181/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8097 - lr: 0.0100 - grad_norm: 0.0182
# Epoch 182/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8102 - lr: 0.0100 - grad_norm: 0.0190
# Epoch 183/10000
# 1/1 [==============================] - 0s 905us/step - energy: -4.8108 - lr: 0.0100 - grad_norm: 0.0200
# Epoch 184/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8114 - lr: 0.0100 - grad_norm: 0.0206
# Epoch 185/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8121 - lr: 0.0100 - grad_norm: 0.0209
# Epoch 186/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8128 - lr: 0.0100 - grad_norm: 0.0209
# Epoch 187/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8136 - lr: 0.0100 - grad_norm: 0.0205
# Epoch 188/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8144 - lr: 0.0100 - grad_norm: 0.0198
# Epoch 189/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8153 - lr: 0.0100 - grad_norm: 0.0186
# Epoch 190/10000
# 1/1 [==============================] - 0s 979us/step - energy: -4.8162 - lr: 0.0100 - grad_norm: 0.0173
# Epoch 191/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8171 - lr: 0.0100 - grad_norm: 0.0159
# Epoch 192/10000
# 1/1 [==============================] - 0s 980us/step - energy: -4.8180 - lr: 0.0100 - grad_norm: 0.0144
# Epoch 193/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8189 - lr: 0.0100 - grad_norm: 0.0128
# Epoch 194/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8197 - lr: 0.0100 - grad_norm: 0.0113
# Epoch 195/10000
# 1/1 [==============================] - 0s 863us/step - energy: -4.8205 - lr: 0.0100 - grad_norm: 0.0099
# Epoch 196/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8213 - lr: 0.0100 - grad_norm: 0.0086
# Epoch 197/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8219 - lr: 0.0100 - grad_norm: 0.0073
# Epoch 198/10000
# 1/1 [==============================] - 0s 942us/step - energy: -4.8226 - lr: 0.0100 - grad_norm: 0.0062
# Epoch 199/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8231 - lr: 0.0100 - grad_norm: 0.0052
# Epoch 200/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8236 - lr: 0.0100 - grad_norm: 0.0043
# Epoch 201/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8240 - lr: 0.0100 - grad_norm: 0.0036
# Epoch 202/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8244 - lr: 0.0100 - grad_norm: 0.0030
# Epoch 203/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8247 - lr: 0.0100 - grad_norm: 0.0025
# Epoch 204/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8249 - lr: 0.0100 - grad_norm: 0.0021
# Epoch 205/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8251 - lr: 0.0100 - grad_norm: 0.0018
# Epoch 206/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8253 - lr: 0.0100 - grad_norm: 0.0016
# Epoch 207/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8255 - lr: 0.0100 - grad_norm: 0.0014
# Epoch 208/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8256 - lr: 0.0100 - grad_norm: 0.0013
# Epoch 209/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8257 - lr: 0.0100 - grad_norm: 0.0013
# Epoch 210/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8257 - lr: 0.0100 - grad_norm: 0.0013
# Epoch 211/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8258 - lr: 0.0100 - grad_norm: 0.0013
# Epoch 212/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8259 - lr: 0.0100 - grad_norm: 0.0013
# Epoch 213/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8259 - lr: 0.0100 - grad_norm: 0.0013
# Epoch 214/10000
# 1/1 [==============================] - 0s 932us/step - energy: -4.8260 - lr: 0.0100 - grad_norm: 0.0013
# Epoch 215/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8260 - lr: 0.0100 - grad_norm: 0.0013
# Epoch 216/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8261 - lr: 0.0100 - grad_norm: 0.0013
# Epoch 217/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8261 - lr: 0.0100 - grad_norm: 0.0012
# Epoch 218/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8262 - lr: 0.0100 - grad_norm: 0.0012
# Epoch 219/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8262 - lr: 0.0100 - grad_norm: 0.0011
# Epoch 220/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8263 - lr: 0.0100 - grad_norm: 0.0010
# Epoch 221/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8264 - lr: 0.0100 - grad_norm: 9.4590e-04
# Epoch 222/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8264 - lr: 0.0100 - grad_norm: 8.5497e-04
# Epoch 223/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8265 - lr: 0.0100 - grad_norm: 7.6492e-04
# Epoch 224/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8265 - lr: 0.0100 - grad_norm: 6.8180e-04
# Epoch 225/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8265 - lr: 0.0100 - grad_norm: 5.9523e-04
# Epoch 226/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8266 - lr: 0.0100 - grad_norm: 5.1426e-04
# Epoch 227/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8266 - lr: 0.0100 - grad_norm: 4.3877e-04
# Epoch 228/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8267 - lr: 0.0100 - grad_norm: 3.7046e-04
# Epoch 229/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8267 - lr: 0.0100 - grad_norm: 3.1057e-04
# Epoch 230/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8267 - lr: 0.0100 - grad_norm: 2.5181e-04
# Epoch 231/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8268 - lr: 0.0100 - grad_norm: 2.0295e-04
# Epoch 232/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8268 - lr: 0.0100 - grad_norm: 1.6341e-04
# Epoch 233/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8268 - lr: 0.0100 - grad_norm: 1.3023e-04
# Epoch 234/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8268 - lr: 0.0100 - grad_norm: 1.0443e-04
# Epoch 235/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8268 - lr: 0.0100 - grad_norm: 8.3355e-05
# Epoch 236/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8268 - lr: 0.0100 - grad_norm: 6.8810e-05
# Epoch 237/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8268 - lr: 0.0100 - grad_norm: 5.8395e-05
# Epoch 238/10000
# 1/1 [==============================] - 0s 929us/step - energy: -4.8268 - lr: 0.0100 - grad_norm: 5.1586e-05
# Epoch 239/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.6325e-05
# Epoch 240/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.3833e-05
# Epoch 241/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.2848e-05
# Epoch 242/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.2468e-05
# Epoch 243/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.2798e-05
# Epoch 244/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.3144e-05
# Epoch 245/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.3797e-05
# Epoch 246/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.3299e-05
# Epoch 247/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.1353e-05
# Epoch 248/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.0359e-05
# Epoch 249/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.6647e-05
# Epoch 250/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.4805e-05
# Epoch 251/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.0165e-05
# Epoch 252/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.7218e-05
# Epoch 253/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.4358e-05
# Epoch 254/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.0177e-05
# Epoch 255/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.7868e-05
# Epoch 256/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.4526e-05
# Epoch 257/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.2324e-05
# Epoch 258/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 9.7851e-06
# Epoch 259/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 7.9702e-06
# Epoch 260/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 5.7058e-06
# Epoch 261/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.5968e-06
# Epoch 262/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.0880e-06
# Epoch 263/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.2773e-06
# Epoch 264/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.2918e-06
# Epoch 265/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 7.4449e-07
# Epoch 266/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 5.5098e-07
# Epoch 267/10000
# 1/1 [==============================] - 0s 959us/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 5.9982e-07
# Epoch 268/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 8.9755e-07
# Epoch 269/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.2393e-06
# Epoch 270/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.3953e-06
# Epoch 271/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.8884e-06
# Epoch 272/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.7570e-06
# Epoch 273/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.9031e-06
# Epoch 274/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.7937e-06
# Epoch 275/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.7470e-06
# Epoch 276/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.5749e-06
# Epoch 277/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.4463e-06
# Epoch 278/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.4741e-06
# Epoch 279/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.5233e-06
# Epoch 280/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.5337e-06
# Epoch 281/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.1029e-06
# Epoch 282/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.0713e-06
# Epoch 283/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 8.8652e-07
# Epoch 284/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 7.1768e-07
# Epoch 285/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.2417e-07
# Epoch 286/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 5.8904e-07
# Epoch 287/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 5.4001e-07
# Epoch 288/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 7.6519e-07
# Epoch 289/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.4475e-07
# Epoch 290/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.4119e-07
# Epoch 291/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 8.2441e-07
# Epoch 292/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.6138e-06
# Epoch 293/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.7731e-06
# Epoch 294/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 5.0432e-06
# Epoch 295/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 7.7531e-06
# Epoch 296/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.1581e-05
# Epoch 297/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.6160e-05
# Epoch 298/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.1454e-05
# Epoch 299/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.7869e-05
# Epoch 300/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.4661e-05
# Epoch 301/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.8386e-05
# Epoch 302/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.2018e-05
# Epoch 303/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.8557e-05
# Epoch 304/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 5.1763e-06
# Epoch 305/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.4597e-07
# Epoch 306/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.3499e-06
# Epoch 307/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.2535e-05
# Epoch 308/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.8140e-05
# Epoch 309/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.5412e-05
# Epoch 310/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.7761e-06
# Epoch 311/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.5933e-07
# Epoch 312/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.0779e-06
# Epoch 313/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.9823e-06
# Epoch 314/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 7.6915e-06
# Epoch 315/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 7.7607e-06
# Epoch 316/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.7843e-06
# Epoch 317/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.2814e-06
# Epoch 318/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 8.5069e-08
# Epoch 319/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.5998e-06
# Epoch 320/10000
# 1/1 [==============================] - 0s 962us/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.0941e-06
# Epoch 321/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.9686e-06
# Epoch 322/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.6362e-06
# Epoch 323/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.4565e-07
# Epoch 324/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.9028e-08
# Epoch 325/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.8678e-07
# Epoch 326/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.3323e-06
# Epoch 327/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.3234e-06
# Epoch 328/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 8.5488e-07
# Epoch 329/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.0422e-07
# Epoch 330/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.0252e-08
# Epoch 331/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.3492e-07
# Epoch 332/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.9340e-07
# Epoch 333/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 9.0248e-07
# Epoch 334/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.2479e-06
# Epoch 335/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.2124e-06
# Epoch 336/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 8.3620e-07
# Epoch 337/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.5654e-07
# Epoch 338/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.7962e-08
# Epoch 339/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.4710e-07
# Epoch 340/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.2235e-07
# Epoch 341/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 5.1086e-07
# Epoch 342/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.3993e-07
# Epoch 343/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.6927e-08
# Epoch 344/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.8283e-08
# Epoch 345/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 8.2714e-08
# Epoch 346/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.5413e-07
# Epoch 347/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.8500e-07
# Epoch 348/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.1026e-06
# Epoch 349/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.4047e-06
# Epoch 350/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.6405e-06
# Epoch 351/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.5077e-06
# Epoch 352/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.1345e-06
# Epoch 353/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.9564e-07
# Epoch 354/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.4615e-07
# Epoch 355/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.1752e-07
# Epoch 356/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.0298e-07
# Epoch 357/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 5.7435e-08
# Epoch 358/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.8708e-08
# Epoch 359/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.3895e-08
# Epoch 360/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.7575e-08
# Epoch 361/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.6223e-07
# Epoch 362/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.2467e-07
# Epoch 363/10000
# 1/1 [==============================] - 0s 964us/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.1187e-07
# Epoch 364/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.0611e-06
# Epoch 365/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.8213e-06
# Epoch 366/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.3852e-06
# Epoch 367/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 5.4582e-06
# Epoch 368/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 8.0196e-06
# Epoch 369/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.0240e-05
# Epoch 370/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.2754e-05
# Epoch 371/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.5593e-05
# Epoch 372/10000
# 1/1 [==============================] - 0s 877us/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.7628e-05
# Epoch 373/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.7227e-05
# Epoch 374/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.4038e-05
# Epoch 375/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 9.2173e-06
# Epoch 376/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.7632e-06
# Epoch 377/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.7306e-06
# Epoch 378/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.4941e-07
# Epoch 379/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 9.9534e-08
# Epoch 380/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.1382e-06
# Epoch 381/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.1758e-06
# Epoch 382/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.0882e-06
# Epoch 383/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 9.0435e-06
# Epoch 384/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.0953e-05
# Epoch 385/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.0791e-05
# Epoch 386/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 9.1353e-06
# Epoch 387/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.5302e-06
# Epoch 388/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.5389e-06
# Epoch 389/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.3670e-06
# Epoch 390/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.7447e-07
# Epoch 391/10000
# 1/1 [==============================] - 0s 870us/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.8313e-07
# Epoch 392/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 9.5148e-07
# Epoch 393/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.8635e-06
# Epoch 394/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.5249e-06
# Epoch 395/10000
# 1/1 [==============================] - 0s 998us/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.0396e-06
# Epoch 396/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.8385e-06
# Epoch 397/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.8903e-06
# Epoch 398/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 8.6848e-07
# Epoch 399/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.1153e-07
# Epoch 400/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 9.1375e-08
# Epoch 401/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 7.2111e-07
# Epoch 402/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.6865e-06
# Epoch 403/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.0560e-06
# Epoch 404/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.2407e-06
# Epoch 405/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.8097e-06
# Epoch 406/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 5.1391e-06
# Epoch 407/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 5.0063e-06
# Epoch 408/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.9133e-06
# Epoch 409/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.5199e-06
# Epoch 410/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.0628e-06
# Epoch 411/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.9236e-06
# Epoch 412/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.7525e-06
# Epoch 413/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.5691e-07
# Epoch 414/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 9.2418e-08
# Epoch 415/10000
# 1/1 [==============================] - 0s 3ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.3418e-07
# Epoch 416/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.0813e-07
# Epoch 417/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.9040e-07
# Epoch 418/10000
# 1/1 [==============================] - 0s 5ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.1000e-06
# Epoch 419/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.3429e-06
# Epoch 420/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.5511e-06
# Epoch 421/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.6564e-06
# Epoch 422/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.5631e-06
# Epoch 423/10000
# 1/1 [==============================] - 0s 991us/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.5987e-06
# Epoch 424/10000
# 1/1 [==============================] - 0s 4ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.3852e-06
# Epoch 425/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.1823e-06
# Epoch 426/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 8.7263e-07
# Epoch 427/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.0108e-07
# Epoch 428/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.6160e-07
# Epoch 429/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.2505e-07
# Epoch 430/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.7494e-07
# Epoch 431/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.2879e-07
# Epoch 432/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 7.4080e-08
# Epoch 433/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.3934e-08
# Epoch 434/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.0748e-07
# Epoch 435/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 8.8235e-07
# Epoch 436/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.2906e-06
# Epoch 437/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.4447e-06
# Epoch 438/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 8.4385e-06
# Epoch 439/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.5921e-05
# Epoch 440/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.8692e-05
# Epoch 441/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 4.3980e-05
# Epoch 442/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 5.8867e-05
# Epoch 443/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.6735e-05
# Epoch 444/10000
# 1/1 [==============================] - 0s 925us/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 5.6979e-05
# Epoch 445/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 3.0751e-05
# Epoch 446/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 6.2789e-06
# Epoch 447/10000
# 1/1 [==============================] - 0s 990us/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 8.8414e-07
# Epoch 448/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.3720e-05
# Epoch 449/10000
# 1/1 [==============================] - 0s 1ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.7975e-05
# Epoch 450/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 2.8117e-05
# Epoch 451/10000
# 1/1 [==============================] - 0s 976us/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.4251e-05
# Epoch 452/10000
# 1/1 [==============================] - 0s 2ms/step - energy: -4.8269 - lr: 0.0100 - grad_norm: 1.5865e-06

# %% [markdown]
# First, observe that the resulting energy (of the new trained circuit) is lower than the separable circuit one!

# %%
print("ENERGY SEPARABLE STATE {}".format(vqe_handler.give_energy(indexed_circuit, resolver)))
print("ENERGY - 1 MUTATION    {}".format(energy2))
# Out:
# ENERGY SEPARABLE STATE (-3.9999999994704822+0j)
# ENERGY - 1 MUTATION    -4.8268938064575195

# %% [markdown]
# Now let us simplify the circuit using the Unitary Killer module

# %%
unitary_killer = UnitaryMurder(vqe_handler, accept_wall=100)
indexed_circuit3, symbol_to_value3, index_to_symbols3, energy3, _ =  unitary_killer.unitary_slaughter(indexed_circuit_1, resolver2, pos2, reference_energy=energy2)
print("Reduced circuit: ")
display(vqe_handler.give_unitary(indexed_circuit3, symbol_to_value3))
# Out:
# I killed 1 unitaries, Ef - Ei: -9.5367431640625e-07
# I killed 2 unitaries, Ef - Ei: -9.5367431640625e-07
# I killed 3 unitaries, Ef - Ei: 0.0008206367492675781
# I killed 4 unitaries, Ef - Ei: 0.004304409027099609
# I killed 5 unitaries, Ef - Ei: 0.008061408996582031
# I killed 6 unitaries, Ef - Ei: 0.059515953063964844
# I killed 7 unitaries, Ef - Ei: 0.059515953063964844
# Reduced circuit:
#                          ┌────────────┐   ┌─────────────────────┐
# (0, 0): ───Rx(-0.114π)───────────────X─────X────────────────────────Rx(-0.082π)───Rz(0.123π)────────────────X───Rx(-0.078π)───Rz(0.436π)───X───
#                                      │     │                                                                │                              │
# (0, 1): ───Rx(-0.236π)────Rz(0.239π)─┼─────┼─────────Rx(-0.125π)────Rz(0.322π)──────────────────────────────┼──────────────────────────────┼───
#                                      │     │                                                                │                              │
# (0, 2): ───Rx(1.81π)──────Rx(-0.131π)┼─────@────────────────────────Rz(0.053π)────Rx(0.076π)───Rz(0.324π)───@──────────────────────────────┼───
#                                      │                                                                                                     │
# (0, 3): ─────────────────────────────@─────Rx(0.291π)───────────────Rz(0.5π)───────────────────────────────────────────────────────────────@───
#                          └────────────┘   └─────────────────────┘

# %%
### Let's compute the ground-state:
H=sum(vqe_handler.observable).matrix()
eigs = np.linalg.eigh(H)
ground_state_energy = eigs[0][0]
ground_state = eigs[1][:,0]

lw=5
ls=30
plt.figure(figsize=(15,10))
plt.subplot(211)
plt.plot(training_history.history["energy"], linewidth=lw, alpha=0.7, color="red", label="Energy - Separable")
plt.plot(np.ones(len(training_history.history["energy"]))*ground_state_energy, '--', linewidth=lw, alpha=0.7, color="blue", label="Ground state energy")
plt.plot(np.ones(len(training_history.history["energy"]))*energy3, linewidth=lw, alpha=0.7, color="green", label="Energy-Mutation 1")

plt.xticks([])
plt.legend(prop={"size":30})
plt.subplot(212)
plt.plot(range(len(training_history.history["energy"] )), np.log10(np.abs(training_history.history["energy"] - ground_state_energy)),  linewidth=lw, alpha=0.7, color="black", label="Separable")
plt.plot(range(len(training_history.history["energy"] ), len(training_history.history["energy"] )+ len(pos2.history["energy"])), np.log10(np.abs(pos2.history["energy"] - ground_state_energy)),  linewidth=lw, alpha=0.7, color="blue", label="Mutation1")
plt.xlabel("epoch",size=ls)
plt.ylabel("Difference w/ \nground state energy",size=int(ls/1.5))
plt.legend(prop={"size":30})

# %% [markdown]
# Vale! we have now see how the basic mechanisms of VANs work and can be implemented to a cirucit. In the next tutorial we will iterate over this in order to find a good alternative to HEA for TFIM.
